# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
import json
import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from plotly.validators.scatter.marker import SymbolsrcValidator

# %%
WINDOW_SIZE=10
cnt = 0
cm_data = pd.read_csv("../data/for_web.csv")
print(cm_data.columns)
col_data = cm_data["n_temp_pv"]
    
new_fig = px.line(x=range(WINDOW_SIZE), y=col_data[cnt:cnt+WINDOW_SIZE], markers=True)
new_fig.update_layout(yaxis_range=[60, 70])
new_fig.show()
# Out:
# Index(['E_scr_pv', 'E_scr_sv', 'c_temp_pv', 'c_temp_sv', 'k_rpm_pv',
#        'k_rpm_sv', 'n_temp_pv', 'n_temp_sv', 's_temp_pv', 's_temp_sv'],
#       dtype='object')
